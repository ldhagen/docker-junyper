# %%
# !pip install scikit-image --upgrade
# Out:
# Collecting scikit-image
#   Downloading scikit-image-0.11.3.tar.gz (18.6MB)
#     100% |################################| 18.6MB 16kB/s
# Requirement already up-to-date: matplotlib>=1.1.0 in /usr/local/lib/python2.7/site-packages (from scikit-image)
# Requirement already up-to-date: six>=1.3 in /usr/local/lib/python2.7/site-packages (from scikit-image)
# Collecting networkx>=1.8 (from scikit-image)
#   Downloading networkx-1.11-py2.py3-none-any.whl (1.3MB)
#     100% |################################| 1.3MB 75kB/s
# Requirement already up-to-date: pillow>=1.7.8 in /usr/local/lib/python2.7/site-packages (from scikit-image)
# Requirement already up-to-date: numpy>=1.6 in /usr/local/lib/python2.7/site-packages (from matplotlib>=1.1.0->scikit-image)
# Requirement already up-to-date: python-dateutil in /usr/local/lib/python2.7/site-packages (from matplotlib>=1.1.0->scikit-image)
# Requirement already up-to-date: pytz in /usr/local/lib/python2.7/site-packages (from matplotlib>=1.1.0->scikit-image)
# Requirement already up-to-date: cycler in /usr/local/lib/python2.7/site-packages (from matplotlib>=1.1.0->scikit-image)
# Requirement already up-to-date: pyparsing!=2.0.4,>=1.5.6 in /usr/local/lib/python2.7/site-packages (from matplotlib>=1.1.0->scikit-image)
# Requirement already up-to-date: decorator>=3.4.0 in /usr/local/lib/python2.7/site-packages (from networkx>=1.8->scikit-image)
# Installing collected packages: networkx, scikit-image
# done
# Successfully installed networkx-1.11 scikit-image-0.11.3

# %%
# !wget http://www7.pcmag.com/media/images/407653-333.jpg?thumb=y
# !mv 407653-333.jpg?thumb=y test2.jpg
# Out:
# --2016-02-24 22:06:18--  http://www7.pcmag.com/media/images/407653-333.jpg?thumb=y
# Resolving www7.pcmag.com (www7.pcmag.com)... 23.216.10.232, 23.216.10.219
# Connecting to www7.pcmag.com (www7.pcmag.com)|23.216.10.232|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35174 (34K) [image/jpeg]
# Saving to: '407653-333.jpg?thumb=y'
#
# 100%[======================================>] 35,174      99.3KB/s   in 0.3s
#
# 2016-02-24 22:06:19 (99.3 KB/s) - '407653-333.jpg?thumb=y' saved [35174/35174]

# %%
# %matplotlib inline
import cv2, pylab
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
image = cv2.imread('test2.jpg')
cv_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(cv_rgb)
plt.show()
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
cv_gray = cv2.cvtColor(cv_rgb,cv2.COLOR_BGR2GRAY)
plt.imshow(cv_gray, cmap=cm.Greys_r)
plt.show()

# %%
from skimage import feature
# Compute the Canny filter for two values of sigma
edges1 = feature.canny(cv_gray)
edges2 = feature.canny(cv_gray, sigma=3)
# display results
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(8, 3),
                                    sharex=True, sharey=True)
ax1.imshow(cv_gray, cmap=plt.cm.gray)
ax1.axis('off')
ax1.set_title('noisy image', fontsize=20)

ax2.imshow(edges1, cmap=plt.cm.gray)
ax2.axis('off')
ax2.set_title('Canny filter, $\sigma=1$', fontsize=20)

ax3.imshow(edges2, cmap=plt.cm.gray)
ax3.axis('off')
ax3.set_title('Canny filter, $\sigma=3$', fontsize=20)

#fig.tight_layout()

plt.show()

# %%
from skimage import feature
# Compute the Canny filter for two values of sigma
edges1 = feature.canny(cv_gray)
edges2 = feature.canny(cv_gray, sigma=2)
plt.imshow(edges2, cmap=cm.Greys_r)
plt.show()

# %%
image = cv2.imread('Screenshot_2016-02-23-12-47-43.png')
cv1_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
cv1_gray = cv2.cvtColor(cv1_rgb,cv2.COLOR_BGR2GRAY)
plt.imshow(cv1_gray, cmap=cm.Greys_r)
plt.show()
